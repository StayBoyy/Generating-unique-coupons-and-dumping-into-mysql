# %% [markdown]
# # Task 6 : Get the dataset on your preference from Kaggle.com and then generate all the Data Visualization graphs accordingly.

# %% [markdown]
# # --->>> Importing the Dependencies
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # This data provides the information about reported rape cases in different States and Union Territories (UTs) of India for the years 2015 and 2016.

# %% [markdown]
# ## The dataset is downloaded from the kaggle.com. Click the below link and verify on your own https://www.kaggle.com/datasets/martandsay/indian-women-rape-molestation-dataset/data?select=RS_Session_246_AU_98_1.1.csv

# %% [markdown]
# ### -->> Reading the file path from the folder and making it availabale

# %%
import zipfile
import os

# Path to the zip file
zip_file_path = r"C:/Users/katra/Downloads/archive.zip"

# Directory to extract to (choose a new directory, not the zip file itself)
extract_dir = r"C:/Users/katra/Downloads/archive"

# Created the extraction directory if it does not exist back again
os.makedirs(extract_dir, exist_ok=True)

# Extracting the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List extracted files
extracted_files = os.listdir(extract_dir)
print(extracted_files)
# Out:
# ['RS_Session_246_AS11.csv']

# %% [markdown]
# ## I Got the dataset as excel format and for easier way I copied the data and list it down

# %% [markdown]
# ## $$ DATASET $$

# %%
# Created the DataFrame from the provided data

data = {
    "States/UTs": ["Andhra Pradesh", "Arunachal Pradesh", "Assam", "Bihar", "Chhattisgarh",
                   "Goa", "Gujarat", "Haryana", "Himachal Pradesh", "Jammu & Kashmir",
                   "Jharkhand", "Karnataka", "Kerala", "Madhya Pradesh", "Maharashtra",
                   "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Odisha", "Punjab",
                   "Rajasthan", "Sikkim", "Tamil Nadu", "Telangana", "Tripura",
                   "Uttar Pradesh", "Uttarakhand", "West Bengal", "Total (States)",
                   "A & N Islands", "Chandigarh", "D&N Haveli", "Daman & Diu", "Delhi UT",
                   "Lakshadweep", "Puducherry", "Total (UTs)", "Total (All-India)"],
    
    "Rape - 2015": [1027, 71, 1733, 1041, 1560, 86, 503, 1070, 244, 296, 1053, 589, 1256,
                    4391, 4144, 46, 93, 58, 35, 2251, 886, 3644, 5, 421, 1105, 213, 3025,
                    283, 1199, 32328, 36, 72, 8, 5, 2199, 0, 3, 2323, 34651],
    
    "Rape - 2016": [994, 92, 1779, 1008, 1626, 61, 982, 1187, 252, 256, 1109, 1655, 1656,
                    4882, 4189, 55, 190, 23, 26, 1983, 838, 3656, 92, 319, 1278, 207, 4816,
                    336, 1110, 36657, 30, 68, 14, 12, 2155, 5, 6, 2290, 38947],
    
    "Assaults (molestation) - 2015": [4616, 101, 4293, 198, 1868, 150, 1164, 1886, 434, 1343,
                                       844, 5112, 3987, 8049, 11713, 84, 95, 75, 8, 6499, 1123,
                                       4813, 21, 1163, 3608, 352, 7885, 318, 5069, 76871, 57, 76,
                                       5, 7, 5367, 6, 33, 5551, 82422],
    
    "Assaults (molestation) - 2016": [4829, 109, 3378, 324, 1770, 143, 1224, 1860, 410, 1235,
                                       667, 5260, 4029, 8717, 11396, 65, 68, 71, 14, 8252, 1025,
                                       4839, 34, 854, 3767, 214, 11335, 344, 4177, 80410, 46, 76,
                                       1, 4, 4165, 1, 43, 4336, 84746],
    
    "Murder (women) - 2015": [428, 9, 185, 340, 338, 11, 269, 197, 25, 19, 137, 574, 97,
                               656, 780, 16, 23, 11, 12, 666, 194, 224, 4, 532, 418, 52,
                               1135, 53, 737, 8142, 8, 3, 3, 1, 124, 0, 10, 149, 8291],
    
    "Murder (women) - 2016": [411, 11, 220, 318, 347, 16, 288, 226, 28, 24, 174, 547, 99,
                               645, 756, 18, 11, 13, 9, 591, 201, 238, 7, 468, 311, 64,
                               1217, 47, 983, 8288, 6, 3, 1, 0, 123, 0, 8, 141, 8429]
}

df = pd.DataFrame(data)

# %% [markdown]
# ## Checking the dataset if NULL or NOT

# %%
# Basic information about the dataset
df.info()

# Descriptive statistics
df.describe()

# Check for missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   States/UTs                     39 non-null     object
#  1   Rape - 2015                    39 non-null     int64
#  2   Rape - 2016                    39 non-null     int64
#  3   Assaults (molestation) - 2015  39 non-null     int64
#  4   Assaults (molestation) - 2016  39 non-null     int64
#  5   Murder (women) - 2015          39 non-null     int64
#  6   Murder (women) - 2016          39 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.3+ KB
# States/UTs                       0
# Rape - 2015                      0
# Rape - 2016                      0
# Assaults (molestation) - 2015    0
# Assaults (molestation) - 2016    0
# Murder (women) - 2015            0
# Murder (women) - 2016            0
# dtype: int64

# %% [markdown]
# #                               Generating different types of Data Visualization graphs
# ____

# %% [markdown]
# # 1 : Bar Graph

# %%
plt.figure(figsize=(17, 10))

# Ploted for 2015
plt.subplot(1, 2, 1)
df.plot(kind='bar', x='States/UTs', y='Rape - 2015', legend=False, ax=plt.gca())
plt.title('Rape Cases-2015')
plt.xlabel('States/UTs')
plt.ylabel('Number of Cases')
plt.xticks(rotation=90)

# Plot for 2016
plt.subplot(1, 2, 2)
df.plot(kind='bar', x='States/UTs', y='Rape - 2016', legend=False, ax=plt.gca())
plt.title('Rape Cases-2016')
plt.xlabel('States/UTs')
plt.ylabel('Number of Cases')
plt.xticks(rotation=90)

plt.tight_layout() # Prevents from overlapping the two plots
plt.show()

# %% [markdown]
# # 2 : Pie Chart

# %% [markdown]
# #### Zoom for clear view

# %%
# Pie chart for 2015 data
plt.figure(figsize=(50, 40))

plt.subplot(3, 1, 3)
plt.pie(df['Rape - 2015'], labels=df['States/UTs'], autopct='%1.1f%%', startangle=140) # Here autopct='%1.1f%% converts into % and then float value
plt.title('Rape Cases Distribution - 2015')

# Pie chart for 2016 data
plt.subplot(3, 2, 3)
plt.pie(df['Rape - 2016'], labels=df['States/UTs'], autopct='%1.1f%%', startangle=140)
plt.title('Rape Cases Distribution - 2016')

plt.tight_layout()
plt.show()
## ZOOM for clear view as it get merge for small values

# %% [markdown]
# # 3 : Histogram

# %%
# Ploting a simple histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Rape - 2015'], bins=10, edgecolor='black', color='skyblue')

# Adding labels and title
plt.title('Distribution of Rape Cases Across States/UTs - 2015')
plt.xlabel('Number of Rape Cases')
plt.ylabel('Number of States/UTs')

# Displaying the plot 
plt.show()
# Here We are ploting it for the year -->> 2015

# %% [markdown]
# # 4 : Line Plot

# %%
x = df["States/UTs"]
y = df["Rape - 2015"]

# Ploting with dark background style
plt.style.use("dark_background")
plt.figure(figsize=(16, 10))

# Simple line plot with markers
plt.plot(x, y, marker='o', color='cyan')

# Adding title and labels
plt.title('Rape Cases in 2015 by States/UTs')
plt.xlabel('States/UTs')
plt.ylabel('Number of Cases')

# Rotated x-axis labels for readability
plt.xticks(rotation=90)

# Adding value annotations directly on the line
for i in range(len(x)):
    plt.text(i, y[i], str(y[i]), ha='center', va='bottom', fontsize=10, color='white') # For clear understanding and matching with our DATASET

plt.show()
# Here We are ploting it for the year -->> 2015

# %% [markdown]
# # 5 :  Scatter Plot

# %%
x = df["States/UTs"]
y = df["Rape - 2015"]

# Ploting with dark background style
plt.style.use("dark_background")
plt.figure(figsize=(16, 10))

# Scatter plot
plt.scatter(x, y, color='cyan', s=100)  # s controls the size of the points

# Adding title and labels
plt.title('Rape Cases in 2015 by States/UTs')
plt.xlabel('States/UTs')
plt.ylabel('Number of Cases')

# Rotated x-axis labels for readability
plt.xticks(rotation=90)

# Adding value annotations directly on the scatter points
for i in range(len(x)):
    plt.text(i, y[i], str(y[i]), ha='center', va='bottom', fontsize=10, color='white')

plt.show()
# Here We are ploting it for the year -->> 2015

# %% [markdown]
# # 6 : Area Plot

# %%
x = df["States/UTs"]
y = df["Rape - 2015"]

# Ploting with dark background style
plt.style.use("dark_background")
plt.figure(figsize=(16, 10))

# Area chart
plt.fill_between(x, y, color='cyan', alpha=0.5)

# Adding title and labels
plt.title('Rape Cases in 2015 by States/UTs')
plt.xlabel('States/UTs')
plt.ylabel('Number of Cases')

# Rotated x-axis labels for readability
plt.xticks(rotation=90)

# Adding value annotations directly on the area chart
for i in range(len(x)):
    plt.text(i, y[i], str(y[i]), ha='center', va='bottom', fontsize=10, color='white')

plt.show()
# Here also We are ploting it for the year -->> 2015

# %% [markdown]
# #  I have ploted above different types of Data visualizations graphs
